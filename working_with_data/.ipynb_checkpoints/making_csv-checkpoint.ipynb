# %%
import subprocess
from pymongo import MongoClient
from nltk.corpus import stopwords
from string import printable
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize
from sys import argv
import pickle
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from dateutil import parser
import datetime
from bs4 import BeautifulSoup
import requests
from unidecode import unidecode
import re

# %%
import os
import re
import operator
import matplotlib.pyplot as plt
import warnings
import gensim
warnings.filterwarnings('ignore')  # Let's not pay heed to them right now

import nltk
nltk.download('stopwords') # Let's make sure the 'stopword' package is downloaded & updated
nltk.download('wordnet') # Let's also download wordnet, which will be used for lemmatization

from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
from pprint import pprint

import numpy as np
import pandas as pd

# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /home/ian/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ian/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
def get_df(db_name):
    url_names = ['cnn', 'abc', 'fox', 'nyt', 'reuters', 'wapo', 'huffpo', 'esquire', 'rollingstone', 'cbs', '538', 'washtimes']
    client = MongoClient()
    db = client[db_name]

    collection_names = db.collection_names()
    my_collection_names = [name for name in collection_names]

    df = pd.DataFrame(columns=['article_text', 'author', 'date_published', 'headline', 'url', 'source'])
    for collection_name in my_collection_names:
        if collection_name != 'system.indexes':
            site = [name for name in url_names if collection_name.startswith(name)]
            if len(site) != 0:
                site = site[0]
                print('Working on '+collection_name)
                for article in db[collection_name].find():
                    # remove article that just have videos
                    # remove powerpost articles from wapo becaue they are 4000+ words
                    if 'video' not in article['url'] and 'powerpost' not in article['url']:
                        try:
                            url = article['url']
                            source = site
                            headline = article['headline']
                            date_published = article['date_published']
                            author = article['author']
                            article_text = article['article_text']
                            # df.append(pd.Series([article_text, author, date_published, headline, url, processed_text, source]), ignore_index=True)
                            df.loc[-1] = [article_text, author, date_published, headline, url, source]  # adding a row
                            df.index = df.index + 1  # shifting index
                            df = df.sort()  # sorting by index
                        except:
                            print('Problem with article in '+site)
    return df

# %%
df = get_df('rss_feeds_new')
# Out:
# Working on washtimes_20170520
# Working on huffpo_20170522
# Working on rollingstone_20170519
# Working on esquire_20170520
# Working on reuters_20170521
# Working on 538_20170522
# Working on fox_20170519
# Working on cbs_20170520
# Working on cnn_20170520
# Working on nyt_20170520
# Working on cbs_20170518
# Working on esquire_20170518
# Working on abc_20170518
# Working on wapo_20170518
# Working on washtimes_20170519
# Working on huffpo_20170518
# Working on abc_20170521
# Working on reuters_20170522
# Working on cnn_20170521
# Working on cbs_20170519
# Working on fox_20170522
# Working on rollingstone_20170520
# Working on esquire_20170522
# Working on cbs_20170521
# Working on washtimes_20170522
# Working on abc_20170522
# Working on abc_20170519
# Working on 538_20170520
# Working on cnn_20170519
# Working on wapo_20170520
# Working on 538_20170519
# Working on huffpo_20170520
# Working on 538_20170521
# Working on washtimes_20170521
# Working on cnn_20170522
# Working on fox_20170518
# Working on reuters_20170519
# Working on nyt_20170521
# Working on cnn_20170518
# Working on rollingstone_20170522
# Working on fox_20170520
# Working on nyt_20170519
# Working on wapo_20170521
# Working on rollingstone_20170521
# Working on 538_20170518
# Working on abc_20170520
# Working on nyt_20170518
# Working on esquire_20170519
# Working on fox_20170521
# Working on nyt_20170522
# Working on wapo_20170522
# Working on cbs_20170601
# Working on washtimes_20170602
# Working on cnn_20170601
# Working on wapo_20170603
# Working on washtimes_20170604
# Working on huffpo_20170602
# Working on nyt_20170531
# Working on cnn_20170531
# Working on nyt_20170602
# Working on cbs_20170531
# Working on cbs_20170603
# Working on esquire_20170602
# Working on rollingstone_20170603
# Working on washtimes_20170601
# Working on 538_20170601
# Working on fox_20170604
# Working on cbs_20170604
# Working on rollingstone_20170601
# Working on 538_20170602
# Working on abc_20170531
# Working on esquire_20170603
# Working on washtimes_20170603
# Working on 538_20170603
# Working on abc_20170603
# Working on rollingstone_20170531
# Working on nyt_20170603
# Working on esquire_20170601
# Working on washtimes_20170531
# Working on huffpo_20170601
# Working on cbs_20170602
# Working on wapo_20170531
# Working on fox_20170602
# Working on esquire_20170531
# Working on rollingstone_20170602
# Working on reuters_20170604
# Working on reuters_20170602
# Working on 538_20170531

# %%
def parse_str(x):
    if isinstance(x, str):
        return unidecode(x)
    else:
        return str(x)
def fix_cnn(df):
    for i in range(df.shape[0]):
        if df['source'][i] == 'cnn':
            url = df['url'][i]
            try:
                result = requests.get(url)
                soup = BeautifulSoup(result.content, 'html.parser')

                tag1 = soup.find('div', attrs={'class': 'el__leafmedia el__leafmedia--sourced-paragraph'}).text
                tag2 = soup.find_all('div', attrs={'class': 'zn-body__paragraph speakable'})
                tag3 = soup.find_all('div', attrs={'class': 'zn-body__paragraph'})
                new_article_text = tag1+' /n '+parse_str(' \n '.join([line.text for line in tag2]))+parse_str(' \n '.join([line.text for line in tag3]))
                df['article_text'][i] = new_article_text
            except:
                print('Problem with article!')
                print(url)
    return df

# %%
df = fix_cnn(df)
df.head()
# Out:
#                                         article_text  \
# 0  Are Moderate Republicans Really Willing To Kil...
# 1  A widely held tenet of the current conventiona...
# 2  Attorney General Jeff Sessions’s tough-on-crim...
# 3  Earlier this week, Deputy Attorney General Rod...
# 4  We Started With 14 Possible Paths For Trump’s ...
#
#                      author      date_published  \
# 0         [Perry Bacon Jr.] 2017-05-31 10:00:49
# 1             [Nate Silver] 2017-05-24 16:23:46
# 2         [Kathryn Casteel] 2017-05-24 04:01:02
# 3            [Clare Malone] 2017-05-19 20:13:40
# 4  [A Fivethirtyeight Chat] 2017-05-24 09:43:33
#
#                                             headline  \
# 0  Are Moderate Republicans Really Willing To Kil...
# 1                   Donald Trump’s Base Is Shrinking
# 2  Jeff Sessions May Be Tough On Crime, But State...
# 3  This Trump-Russia Investigation Could Last For...
# 4  We Started With 14 Possible Paths For Trump’s ...
#
#                                                  url source
# 0  https://fivethirtyeight.com/features/are-moder...    538
# 1  https://fivethirtyeight.com/features/donald-tr...    538
# 2  https://fivethirtyeight.com/features/jeff-sess...    538
# 3  https://fivethirtyeight.com/features/this-trum...    538
# 4  https://fivethirtyeight.com/features/we-starte...    538

# %%
def parse_str(x):
    if isinstance(x, str):
        return unidecode(x)
    else:
        return str(x)
def fix_huffpo(df):
    for i in range(df.shape[0]):
        if df['source'][i] == 'huffpo':
            url = df['url'][i]
            try:
                result = requests.get(url)
                soup = BeautifulSoup(result.content, 'html.parser')

                tag = soup.find_all('div', attrs={'class': 'content-list-component bn-content-list-text text'})
                new_article_text = parse_str(' \n '.join([line.text for line in tag]))
                df['article_text'][i] = new_article_text
            except:
                print('Problem with article!')
                print(url)
    return df

# %%
df = pd.read_csv('../data/rss_feeds_new.csv')
df = fix_huffpo(df)
df[df['source'] == 'huffpo'].head()
# Out:
#     article_text                                             author  \
# 219               ['Kate Sheppard', 'Akbar Shahid Ahmed', 'Nick ...
# 220                        ['Sara Boboltz', 'Entertainment Editor']
# 221                                      ['David Moye', 'Reporter']
# 222                                ['Antonia Blumberg', 'Reporter']
# 223                                                              []
#
#               date_published  \
# 219  2017-06-01 00:00:00.000
# 220  2017-06-01 00:00:00.000
# 221  2017-06-01 00:00:00.000
# 222  2017-06-01 00:00:00.000
# 223  2017-06-01 00:00:00.000
#
#                                               headline  \
# 219  Trump's Not Just Ruining The Planet. He's Losi...
# 220  Leonardo DiCaprio Calls For Action After Trump...
# 221  Twitter Mercilessly Mocks Sean Hannity For Whi...
# 222  Vatican Sees U.S. Climate Accord Withdrawal As...
# 223    EPA Starts Offering Buyouts In Bid To Cut Staff
#
#                                                    url  \
# 219  http://www.huffingtonpost.com/2017/06/01/trump...
# 220  http://www.huffingtonpost.com/2017/06/01/leona...
# 221  http://www.huffingtonpost.com/2017/06/01/sean-...
# 222  http://www.huffingtonpost.com/2017/06/01/vatic...
# 223  http://www.huffingtonpost.com/2017/06/01/epa-b...
#
#                                         processed_text  \
# 219  washington environmental implication united st...
# 220  climate change activist leonardo dicaprio offe...
# 221  sean hannity proved seth rich handle truth sho...
# 222  barely week meeting pope francis promising rea...
# 223  washington june 1 reuters u environmental prot...
#
#                                        processed_quote  source  \
# 219  punishes united state negotiate way back paris...  huffpo
# 220  america first hoax flood important ever take a...  huffpo
# 221  investigation hundred miniature sean hannitys ...  huffpo
# 222  really pull would huge slap face u disaster ev...  huffpo
# 223  early out buy out help u realign workforce mee...  huffpo
#
#                                     sentiment_of_words  \
# 219  {'environmental': [0.0, 0.0625, 0.9375, -0.003...
# 220  {'trump': [0.017857142857142856, 0.0, 0.982142...
# 221  {'sean': [0, 0, 0, 0], 'seth': [0.0, 0.0, 1.0,...
# 222  {'barely': [0.0625, 0.1875, 0.75, -0.03125], '...
# 223  {'u': [0.0, 0.0, 1.0, 0.0], 'environmental': [...
#
#                                   probability_of_topic  \
# 219  [0.014832362764803264, 0.059127397003156119, 0...
# 220  [0.015001550910337471, 0.052853741983540384, 0...
# 221  [0.014391083614490256, 0.048882591286194002, 0...
# 222  [0.021256505436694072, 0.062841562766928996, 0...
# 223  [0.015660155134319922, 0.084063956924650837, 0...
#
#                                              sentiment  \
# 219  {19: (7.9578126118395973, 6.47320569921333, 20...
# 220  {19: (7.0028258003264874, 4.8252651363870971, ...
# 221  {19: (9.9971567643908479, 2.6601630578775448, ...
# 222  {19: (7.527172569051559, 4.0286458228956619, 2...
# 223  {19: (6.0220844965182501, 6.3602707417573061, ...
#
#                                        processed_tweet
# 219  deeply disappointed united state federal gover...
# 220  take action supporting organization front line...
# 221  wrong left think sort thing funny http co saxo...
# 222  climate change represents one principal challe...
# 223                                                NaN

# %%
def clean_df(df):
    # Remove duplicates by url
    df = df.drop_duplicates(subset='url')
    # Below I get rid of large articles that could throw off my algorithms
    # Remove two article types that were very long
    # any url with speech was just a transcript of speeches
    df = df[(df['source'] != 'ap') & (df['source'] != 'economist') & (df['source'] != 'vox') & (df['source'] != 'time') & (df['source'] != 'slate')]

    df[df['source'] == 'wapo'] = df[(df['source'] == 'wapo') & (df['url'].str.contains('powerpost') == False) & (df['url'].str.contains('-speech-') == False)]
    df[df['source'] == 'economist'] = df[(df['source'] == 'economist') & (df['url'].str.contains('transcript') == False)]
    df[df['source'] == 'fox'] = df[(df['source'] == 'fox') & (df['article_text'].str.contains('Want FOX News Halftime Report in your inbox every day?') == False)]
    df[df['source'] == 'esquire'] = df[(df['source'] == 'esquire') & (df['url'].str.contains('-gallery-') == False)]

    # Can't have null values in text
    df = df[pd.notnull(df['article_text'])]
    df = df.dropna(how='all')
    return df

# %%
df = clean_df(df)
df.head()
# Out:
#                                         article_text  \
# 0  Are Moderate Republicans Really Willing To Kil...
# 1  A widely held tenet of the current conventiona...
# 2  Attorney General Jeff Sessions’s tough-on-crim...
# 3  Earlier this week, Deputy Attorney General Rod...
# 4  We Started With 14 Possible Paths For Trump’s ...
#
#                      author      date_published  \
# 0         [Perry Bacon Jr.] 2017-05-31 10:00:49
# 1             [Nate Silver] 2017-05-24 16:23:46
# 2         [Kathryn Casteel] 2017-05-24 04:01:02
# 3            [Clare Malone] 2017-05-19 20:13:40
# 4  [A Fivethirtyeight Chat] 2017-05-24 09:43:33
#
#                                             headline  \
# 0  Are Moderate Republicans Really Willing To Kil...
# 1                   Donald Trump’s Base Is Shrinking
# 2  Jeff Sessions May Be Tough On Crime, But State...
# 3  This Trump-Russia Investigation Could Last For...
# 4  We Started With 14 Possible Paths For Trump’s ...
#
#                                                  url source
# 0  https://fivethirtyeight.com/features/are-moder...    538
# 1  https://fivethirtyeight.com/features/donald-tr...    538
# 2  https://fivethirtyeight.com/features/jeff-sess...    538
# 3  https://fivethirtyeight.com/features/this-trum...    538
# 4  https://fivethirtyeight.com/features/we-starte...    538

# %%
# df = pd.read_csv('../data/rss_feeds_new.csv')
# df = df[pd.notnull(df['processed_text'])]
# text = df['processed_text'].values.tolist()
if False:
    df = pd.read_csv('../data/rss_feeds_new.csv')
df = df[pd.notnull(df['article_text'])]

# %%
def get_article_length_hist(df):
    site_article_length = {source: [] for source in df['source'].unique()}
    for source in df['source'].unique():
        new_df = df[df['source'] == source]
        for article in new_df['article_text']:
            site_article_length[source].append(len(article.split()))


    for i, source in enumerate(site_article_length.keys()):
        plt.subplot(4,3,i+1)
        plt.hist(site_article_length[source], normed=True, bins=100)
        plt.title('Article Length '+source)
    plt.subplots_adjust(hspace=0.4, wspace=0.4)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 10)

get_article_length_hist(df)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df.to_csv('rss_feeds_new_good.csv')
